# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
ypoints = np.array([3,8,1, 10])
y = pd.Series([3,8,1, 10], index=['one', 'two','three','four'])

print(y)
plt.plot(ypoints, marker = '4')
plt.show()

plt.plot(y, marker = '4')
plt.show()

# %%
plt.subplot(3,4 , 1)
plt.plot(ypoints, marker = '4')

plt.subplot(1,2, 2)
plt.plot(y, marker = '4')
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
#plt.grid()
plt.scatter(x, y)
plt.show()

# %%
data1 = [23,85, 72, 43, 52]
data2 = [42, 35, 21, 16, 9]
width =0.4
plt.bar(np.arange(len(data1)), data1, width=width)
plt.bar(np.arange(len(data2))+ width, data2, width=width)
plt.show()

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
x = [10, 50, 30, 20]
labels = ['Surfing', 'Soccer', 'Baseball', 'Lacrosse']

fig, ax = plt.subplots()
ax.pie(x, labels=labels)
ax.set_title('Sport Popularity')
plt.tight_layout()
# Out:
# Figure(640x480)

# %%
y = ["1980","1981","1982","1983","1984"]
data = {"India":[8880,8670,8147,7338,5704], "China":[5123,6682,3308,1863,1527]}

df = pd.DataFrame(data, index=y)

df["India"].plot(kind="hist")
df
# Out:
#       India  China
# 1980   8880   5123
# 1981   8670   6682
# 1982   8147   3308
# 1983   7338   1863
# 1984   5704   1527

# %%
plt.hist(df["India"], bins=3, edgecolor="black", rwidth=0.5)
plt.show()
df
# Out:
#       India  China
# 1980   8880   5123
# 1981   8670   6682
# 1982   8147   3308
# 1983   7338   1863
# 1984   5704   1527
